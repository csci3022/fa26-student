# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw03.ipynb")

# %% [markdown]
# # Homework 3
# ## Exploratory Data Analysis (EDA) and Visualization
# ## Due Date: Wednesday, September 9th by 11:59 PM MT on Gradescope
#
#
#
# ### Detailed Submission Instructions Are Provided at the end of this Notebook
#
#
# ## Assignment Learning Objectives:
#
#
# 1. Perform tasks to clean, visualize, and explore data
# 2. Think critically about how plots provide insight into the data.
# 3. Wrangle data for analysis
# 4. Use EDA to learn about your data
# 5. Choose appropriate types of visualization for given feature types.
#
# ## Collaboration and Generative AI Policy
#
# Data science is collaborative, but a key part of learning is **doing the intellectual work yourself**. Homework is not just about getting the correct answer—it is practice for developing the reasoning and conceptual understanding you will need on quizzes and exams.
#
# You may discuss concepts, ask for help when you are stuck, and use approved references, but the solutions you submit must be your own. **You should be able to independently reproduce, explain, and justify any work you submit if asked by an instructor or TA.** More importantly, you should understand the underlying concepts well enough to recognize when they apply and use them in a new problem or context.
#
# ### If You Choose to Use HiTA (https://www.hita.ai/)
#
# HiTA is an optional GenAI tutoring tool available specifically for this course. It is permitted because it is designed to support learning rather than replace it. HiTA provides explanations, hints, questions, and guidance while leaving the substantive reasoning and problem-solving to you.
#
# HiTA is the only permitted Gen-AI tool in this course. ChatGPT, Gemini, Claude, Copilot, and **other generative AI tools may not be used to obtain assistance on course assignments**.
#
# If you choose to use HiTA, treat it as a **last resort for help, not a first step toward a solution**. Homework is an opportunity to practice the conceptual reasoning and problem-solving skills you will need on quizzes and exams, where GenAI will not be available.
#
# Use the following guidelines:
#
# 1. **Try the problem yourself first—and give yourself time to struggle with it.** Productive struggle is an important part of learning. Before asking HiTA for help, work on the problem long enough to identify what you understand, what you do not understand, and exactly where your reasoning breaks down. If possible, give yourself some time away from the problem before turning to HiTA; continuing to think about a difficult concept, even when you are not actively working on it, is part of developing the problem-solving skills you will need on exams.
#
# 2. **Ask for guidance, not answers.** If you are still stuck, ask HiTA for a hint, conceptual explanation, or help understanding why an approach might or might not work. Do not ask it to select the method, carry out the substantive reasoning, or produce the complete solution for you.
#
# 3. **Focus on why, not just how.** Getting the correct homework answer is not the goal—the goal is learning the underlying concepts. Being able to reproduce an algorithm or sequence of calculations does not necessarily mean you understand it. You should be able to explain why a method works, when it applies, when it does not apply, and how to use the same underlying idea in a substantially different problem or application.
#
# 4. **Evaluate HiTA critically.** HiTA can make mistakes. If you already have a solution that you believe is correct, you may use HiTA to critique or check your reasoning, but do not assume its response is correct simply because it sounds convincing. GenAI can hallucinate or provide incorrect reasoning, so if HiTA's response conflicts with your understanding or leaves you uncertain, check with Course Staff on Piazza or during Office Hours before relying on it.
#
# 5. **Return to the problem independently.** After receiving help from HiTA, put its response aside and work through the problem yourself. You should be able to reconstruct and explain the reasoning without referring back to HiTA. If you cannot, you have not yet learned the material well enough and should continue working on the concept or seek help from Course Staff.
#
# A good test is whether using HiTA ultimately makes you **better able to solve problems without HiTA**. If you become dependent on it whenever you are uncertain, you are practicing the opposite of the skill you will need on quizzes, exams, and in later courses.
#
# The key principle is to **avoid cognitive offloading**: do not transfer to HiTA the thinking and reasoning that you need to learn to do yourself.
#
# #### Homework and Project Collaboration: Permitted and Not Permitted
#
# The following are **violations** of the CSCI 3022 Academic Honesty and Collaboration Policy:
#
# - Consulting a webpage or other source that contains a solution to the assigned problem or a similar problem.
# - Reading another student's solution before writing your own.
# - Copying another student's work or an online solution and then editing or modifying it.
# - Copying three or more lines of code or mathematical work from another student, or allowing another student to copy three or more lines of your work.
# - Asking someone else to write all or part of a program or solution for you, or to provide the code needed to fix an error except for simple syntax errors.
# - Having another person or a GenAI tool convert an entire solution, or a substantial portion of one, into LaTeX for you.
# - Copying, pasting, or uploading assignment text or screenshots into any GenAI tool other than HiTA.
# - Searching Google or asking a GenAI tool other than HiTA an identical or substantially similar question to one appearing on an assignment.
# - Using any GenAI tool other than HiTA to solve, check, rewrite, or substantially complete an assignment problem.
# - Using HiTA to obtain a complete solution rather than an explanation, hint, or guidance.
# - Submitting an exact or lightly edited solution generated by an LLM, including HiTA.
# - Falsifying evidence that you submitted an assignment,
#
# The following are **permitted**:
#
# - Working on a problem independently first, then discussing a specific point where you are stuck and returning to complete your solution independently.
# - Looking up individual programming or LaTeX commands and syntax.
# - Asking how a programming or LaTeX construct works or why it is not behaving as expected.
# - Asking someone to help you find or understand an error in your program without providing the solution for you.
# - Consulting course notes, the textbook, or references that provide syntax, formulas, or conceptual explanations without providing a solution to the assigned problem.
# - Using HiTA for permitted forms of assistance, such as conceptual explanations, hints, clarification, or guidance that helps you develop and understand your own solution.
#
# The key distinction is whether a resource is helping you learn how to do the work yourself or is doing part of the intellectual work for you. Your submitted work must be your own, and you should be able to independently explain and reproduce it if asked. When in doubt, rely on the course notes, course textbook, and references that provide syntax and/or formulas, or ask the instructional staff.

# %% [markdown]
# ## Grading
# Grading is broken down into autograded answers and free response.
#
# For autograded answers, the results of your code are compared to provided and/or hidden tests.
#
# For free response, readers will evaluate how well you answered the question and/or fulfilled the requirements of the question.
#
# For plots, your plots should be *similar* to the given examples. We will tolerate small variations such as color differences or slight variations in scale. However it is in your best interest to make the plots as similar as possible, as similarity is subject to the readers.
#
# **Note that for ALL plotting questions from here on out, we will expect appropriate titles, axis labels, legends, etc. The following question serves as a good guideline on what is "enough": If I directly downloaded the plot and viewed it, would I be able to tell what was being visualized without knowing the question?**
#
# ### Score breakdown
#
#
#
# Question | Points | Grading Type
# --- | --- | ---
# Question 1a | 4 | autograded
# Question 1b | 2 | autograded
# Question 1c | 2 | autograded
# Question 1d | 2 | autograded
# Question 2a | 2 | autograded
# Question 2b | 2 | autograded
# Question 2c | 3 | manual
# Question 2d | 2 | autograded
# Question 2e | 4 | manual
# Question 2f | 3 | manual
# Question 3a| 4 | autograded
# Question 3b | 3 | autograded
# Question 3c | 6 | manual (2), autograded (4)
# Question 3d | 3 | manual
# Question 3e | 3 | manual (2), autograded (1)
# Question 4  | 5 | autograded
# |Total | 50
#
#
#
# ## Recommended Readings for this HW:
#
# - [Learning Data Science Chapter 9 - All (Wrangling DataFrames)](https://learningds.org/ch/09/wrangling_intro.html)
# - [Learning Data Science Chapter 10 - All (EDA)](https://learningds.org/ch/10/eda_intro.html)
# - [Learning Data Science Chapter 11 - All (Visualization)](https://learningds.org/ch/11/viz_intro.html)
# - [Learning Data Science 13.2 - String Manipulation](https://learningds.org/ch/13/text_strings.html)

# %% [markdown]
# ### Matplotlib and Seaborn Table of Common Functions
#
# `x` and `y` are sequences of values (i.e. arrays, lists, or Series).
#
# | Function | Description |
# | -------- | ----------- |
# | `sns.lineplot(data = df, x= 'col1', y='col2')` | Creates a line plot of `col1` vs `col2`  using columns from dataframe df |
# | `plt.plot(x, y)` | Creates a line plot of `x` against `y` |
# | `plt.title(name)` | Adds a title `name` to the current plot |
# | `plt.xlabel(name)` | Adds a label `name` to the x-axis |
# | `plt.ylabel(name)` | Adds a label `name` to the y-axis |
# | `plt.scatter(x, y)` | Creates a scatter plot of `x` against `y` |
# | `plt.barh(y, length)` | Creates a bar plot of categories `y` and corresponding lengths `length` |
# | `plt.hist(x, bins=None, density=True)` | Creates a density histogram of `x`; `bins` can be an integer or a sequence |
# | `sns.countplot(data, x=col);` | Creates a vertical bar plot with counts of different values of `col` (which is a column in the `data`  DataFrame |
# | `sns.countplot(data, y=col);` | Creates a horizontal bar plot with counts of different values of `col` (which is a column in the `data`  DataFrame |
# | `sns.histplot(data, x, y, hue, kde, stat)` | Creates a distribution plot; `data` is a DataFrame; `x`, `y` are column names in `data` that specify positions on the x and y axes; `hue` is a column name in `data` that adds subcategories to the plot based on `hue`; `kde` is a boolean that determines whether to overlay a KDE curve; `stat=density` will create a density plot |
# |`sns.kdeplot(x, y)` |  Creates a kernel density estimate plot; `x`, `y` are series of data that indicate positions on the `x` and `y` axis |
#
#
# **Note**: This list of functions and parameters is **not** exhaustive. You may need to reference and explore more documentation to answer the following questions, but we will help you through that process.

# %% [markdown]
# ---
# ## Setup
#
# In this assignment we'll be providing some tips for working with matplotlib (a Python plotting library). Note that we configure a custom default figure size. Virtually every default aspect of matplotlib [can be customized](https://matplotlib.org/users/customizing.html).

# %%
# Run this cell to import all the libraries we will be using
import pandas as pd
import numpy as np
import zipfile
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import simple_latex_checker as slc

import hashlib
def get_hash(num):
    """Helper function for assessing correctness"""
    return hashlib.md5(str(num).encode()).hexdigest()




plt.rcParams['figure.figsize'] = (12, 9)

# %% [markdown]
# <br/><br/>
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 1: Acquire the Data
#
# **1. Obtain data**<br/>  In this HW, we'll be working with a dataset gathered by the Berkeley Police Department with a record of Calls for Service.
#
# That is, the **granularity** of this dataset is that each row represents data from a **single call** (either telephone, 911 or officer initatied call) to the dispatchers at the Berkeley Police Department.
#
# The data is stored in the `data/BerkeleyPDCalls.csv` file.
#
# **2. Load data**<br/>
# Let's now load the CSV file we have into a `pandas.DataFrame` object and start exploring the data.

# %%
calls = pd.read_csv("data/BerkeleyPDCalls.csv")

# %% [markdown]
# ---
#
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 1:  Examining the Data ##
#
# Read the description of the columns available here (note that the date range of the data we will be analyzing is different than the date on this website, but the columns are the same):  https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5
#
# Before we start working with the data, let's examine it.
# Look at the the first 10 rows:

# %%
#your code here to select the first 10 rows
...

# %% [markdown]
# We see that the fields include a case number, the offense type, the date and time of the offense, the "CVLEGEND" which appears to be related to the offense type, a "CVDOW" which has no apparent meaning, the date the record was added to the database, and the location spread across four fields. We can read more about each field from the City of Berkeley's [open dataset webpage](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5).

# %% [markdown]
# ### Examining the Temporality of the data

# %% [markdown]
# Let's determine what timeframe the data spans.  We'll use the `EVENTDT` field.

# %%
# Run this cell
calls['EVENTDT'].max()
# Out:
# '12/31/2020 12:00:00 AM'

# %%
# Run this cell
calls['EVENTDT'].min()
# Out:
# '01/01/2021 12:00:00 AM'

# %% [markdown]
# **Warning!** Note that there's a problem with our code above! According to the output our data only spans a total of 1 day (24 hours). Clearly something is incorrect.  Let's examine how to fix this.
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 1a (4 pts)
#
# Throughout this assignment we're frequently going to ask you to explore some new syntax that we haven't seen in lecture. Don't panic!  This is an important skill in data science.   If you're not sure what to do, try experimenting, Googling, and don't shy away from talking to other students or course staff.
#
#
#
# **Part 1a(i)** What is the storage type of the individual `calls['EVENTDT']` entries?  Grab the very first entry in the `EVENTDT` column and use the `type` (https://www.w3schools.com/python/ref_func_type.asp) function in Python.  Assign your answer to the variable `eventdt_type`

# %%
eventdt_type = ...

eventdt_type
# Out:
# Ellipsis

# %%
grader.check("q1ai")
# Out:
# q1ai results:
#     q1ai - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(eventdt_type) == '9a86641cdf2fdb47f786dc955264738d'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1ai 0
#         Failed example:
#             assert get_hash(eventdt_type) == '9a86641cdf2fdb47f786dc955264738d'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1ai 0[0]>", line 1, in <module>
#                 assert get_hash(eventdt_type) == '9a86641cdf2fdb47f786dc955264738d'
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError

# %% [markdown]
# **Part 1a(ii)** Rather than the type you discovered in 1a(i), we want each event date entry in `pd.TimeStamp` format.
#
# Read more about this format in [Section 9.4 of the class textbook Learning Data Science](https://learningds.org/ch/09/wrangling_transformations.html).
#
# Using `pd.to_datetime()`(https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html), add a new column to the `calls` database called `EVENT_TS` that converts the `EVENTDT` to TimeStamp format.  (For this problem ignore the EVENTTM entries and just convert the EVENTDT values).
#
# Then use this new column to determine the earliest and latest dates in the `EVENT_TS` column and assign this output to the variables `first_event_timestamp` and `last_event_timestamp`.  Note your answers should be in TimeStamp format.  (Use code to find these values, don't enter manually).

# %%
 

...

# It's ok if you get a warning from Python about not specifying the exact date format-
# you can ignore the warning in this case because to_datetime parses correctly for our data
calls.head()

# Your code adding the column `EVENT_TS` above
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1  21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2  21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3  21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4  21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
#
#              CVLEGEND  CVDOW                InDbDate  \
# 0             LARCENY      4  06/15/2021 12:00:00 AM
# 1             LARCENY      4  06/15/2021 12:00:00 AM
# 2             LARCENY      1  06/15/2021 12:00:00 AM
# 3             LARCENY      6  06/15/2021 12:00:00 AM
# 4  BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
#
#                                       Block_Location                BLKADDR  \
# 0             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 1             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 2  2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...    2100 BLOCK HASTE ST
# 3  2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...  2600 BLOCK WARRING ST
# 4  2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...   2700 BLOCK GARBER ST
#
#        City State
# 0  Berkeley    CA
# 1  Berkeley    CA
# 2  Berkeley    CA
# 3  Berkeley    CA
# 4  Berkeley    CA

# %%
first_event_timestamp = ...

last_event_timestamp = ...

#The line below just prints out your results
[first_event_timestamp, last_event_timestamp]
# Out:
# [Ellipsis, Ellipsis]

# %%
grader.check("q1aii")
# Out:
# q1aii results:
#     q1aii - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(calls.shape[1]) == 'c20ad4d76fe97759aa27a0c99bff6710'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1aii 0
#         Failed example:
#             assert get_hash(calls.shape[1]) == 'c20ad4d76fe97759aa27a0c99bff6710'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1aii 0[0]>", line 1, in <module>
#                 assert get_hash(calls.shape[1]) == 'c20ad4d76fe97759aa27a0c99bff6710'
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError
#
#     q1aii - 2 result:
#         ✅ Test case passed
#
#     q1aii - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(calls.loc[1, 'EVENT_TS']) == 'cd5252ea65ebc95fc2ae8c56fb9e3b19'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1aii 2
#         Failed example:
#             assert get_hash(calls.loc[1, 'EVENT_TS']) == 'cd5252ea65ebc95fc2ae8c56fb9e3b19'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                 return self._engine.get_loc(casted_key)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#               File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#             KeyError: 'EVENT_TS'
#
#             The above exception was the direct cause of the following exception:
#
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1aii 2[0]>", line 1, in <module>
#                 assert get_hash(calls.loc[1, 'EVENT_TS']) == 'cd5252ea65ebc95fc2ae8c56fb9e3b19'
#                                 ~~~~~~~~~^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                 return self.obj._get_value(*key, takeable=self._takeable)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                 series = self._get_item_cache(col)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                 loc = self.columns.get_loc(item)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                 raise KeyError(key) from err
#             KeyError: 'EVENT_TS'
#
#     q1aii - 4 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(last_event_timestamp) == '2af487344588f060428f9a266e280876'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1aii 3
#         Failed example:
#             assert get_hash(last_event_timestamp) == '2af487344588f060428f9a266e280876'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1aii 3[0]>", line 1, in <module>
#                 assert get_hash(last_event_timestamp) == '2af487344588f060428f9a266e280876'
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError
#
#     q1aii - 5 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(first_event_timestamp) == 'c0fb5f8c6c2f8e397fe28d3358c31417'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1aii 4
#         Failed example:
#             assert get_hash(first_event_timestamp) == 'c0fb5f8c6c2f8e397fe28d3358c31417'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1aii 4[0]>", line 1, in <module>
#                 assert get_hash(first_event_timestamp) == 'c0fb5f8c6c2f8e397fe28d3358c31417'
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError

# %% [markdown]
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 2: Clean and Explore the Data

# %% [markdown]
# We see that the fields include a case number, the offense type, the date and time of the offense, the "CVLEGEND" which appears to be related to the offense type, a "CVDOW" which has no apparent meaning, a date added to the database, and the location spread across four fields. We can read more about each field from the City of the Berkeley's [open dataset webpage](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5).
#
# Let's also check some basic information about this DataFrame using the `DataFrame.info` ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)) and `DataFrame.describe` methods ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)).

# %%
# use the .info() method on the Calls DataFrame:
...

# %% [markdown]
# Note that the `BLKADDR` column only has 2612 non-null entries, while the other columns all have 2632 entries.
# This is because the `.info()` method only counts non-null entries.

# %%
#use the .describe() method on the calls DataFrame:
...

# %% [markdown]
# Notice that the functions above reveal type information for the columns, as well as some basic statistics about the numerical columns found in the DataFrame. However, we still need more information about what each column represents. Let's explore the data further.

# %% [markdown]
# Before we go over the fields to see their meanings, the cell below will verify that all the events happened in Berkeley by grouping on the `City` and `State` columns. You should see that all of our data falls into one group.

# %%
calls.groupby(["City","State"]).count()
# Out:
#                 CASENO  OFFENSE  EVENTDT  EVENTTM  CVLEGEND  CVDOW  InDbDate  \
# City     State
# Berkeley CA       2632     2632     2632     2632      2632   2632      2632
#
#                 Block_Location  BLKADDR
# City     State
# Berkeley CA               2632     2612

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 1b (2 pts)
#
# When we called `head()` on the Dataframe `calls`, it seemed like `OFFENSE` and `CVLEGEND` both contained information about the type of event reported. To determine the difference in meaning between the two columns, create a series called `offense_counts` with the counts of unique values in the `OFFENSE` column and a 2nd series called `cvlegend_counts` with the counts of unique values in the `CVLEGEND` column  .

# %%
offense_counts= ...

cvlegend_counts= ...

print(offense_counts.head(10))

print(cvlegend_counts.head(10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 5
#       1 offense_counts= ...
#       3 cvlegend_counts= ...
# ----> 5 print(offense_counts.head(10))
#       7 print(cvlegend_counts.head(10))
#
# AttributeError: 'ellipsis' object has no attribute 'head'

# %%
grader.check("1b")
# Out:
# 1b results:
#     1b - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(offense_counts['ASSAULT/BATTERY MISD.']) == 'c45147dee729311ef5b5c3003946c48f'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in 1b 0
#         Failed example:
#             assert get_hash(offense_counts['ASSAULT/BATTERY MISD.']) == 'c45147dee729311ef5b5c3003946c48f'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest 1b 0[0]>", line 1, in <module>
#                 assert get_hash(offense_counts['ASSAULT/BATTERY MISD.']) == 'c45147dee729311ef5b5c3003946c48f'
#                                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not subscriptable
#
#     1b - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(cvlegend_counts.size) == 'b6d767d2f8ed5d21a44b0e5886680cb9'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in 1b 1
#         Failed example:
#             assert get_hash(cvlegend_counts.size) == 'b6d767d2f8ed5d21a44b0e5886680cb9'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest 1b 1[0]>", line 1, in <module>
#                 assert get_hash(cvlegend_counts.size) == 'b6d767d2f8ed5d21a44b0e5886680cb9'
#                                 ^^^^^^^^^^^^^^^^^^^^
#             AttributeError: 'ellipsis' object has no attribute 'size'
#
#     1b - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(cvlegend_counts['ASSAULT']) == '7ef605fc8dba5425d6965fbd4c8fbe1f'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in 1b 2
#         Failed example:
#             assert get_hash(cvlegend_counts['ASSAULT']) == '7ef605fc8dba5425d6965fbd4c8fbe1f'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest 1b 2[0]>", line 1, in <module>
#                 assert get_hash(cvlegend_counts['ASSAULT']) == '7ef605fc8dba5425d6965fbd4c8fbe1f'
#                                 ~~~~~~~~~~~~~~~^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not subscriptable

# %% [markdown]
# It seems like `OFFENSE` is more specific than `CVLEGEND`, e.g. "LARCENY" vs. "THEFT FELONY (OVER $950)".
#
# If you're unfamiliar with the term, "larceny" is a legal term for theft of personal property.

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 1c (2 pts)
#
# If you haven't already, read the required textbook reading on aggregating:  [LDS: 6.2- Aggregating](https://learningds.org/ch/06/pandas_aggregating.html).
#
# To get a sense of how many subcategories there are for each `OFFENSE`, create a **multi-indexed** `series` called `calls_by_cvlegend_and_offense`  where the data is first indexed on the `CVLEGEND` and then on the `OFFENSE`, and the data is equal to the number of offenses in the database that match the respective `CVLEGEND` and `OFFENSE`.
#
#
# For example, `calls_by_cvlegend_and_offense["LARCENY", "THEFT FROM PERSON"]` should return the value 8 which means there are 8 instances of larceny with offense of type "THEFT FROM PERSON" in the database.
#
# Make sure your final answer is a multi-indexed **Series**, not a DataFrame  (Hint: if you end up with a DataFrame, you can convert from a multiindexed DataFrame to a mult-indexed Series using `ser = df.squeeze()` (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.squeeze.html) )

# %%
calls_by_cvlegend_and_offense = ...



calls_by_cvlegend_and_offense["LARCENY", "THEFT FROM PERSON"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       1 calls_by_cvlegend_and_offense = ...
# ----> 5 calls_by_cvlegend_and_offense["LARCENY", "THEFT FROM PERSON"]
#
# TypeError: 'ellipsis' object is not subscriptable

# %%
grader.check("1c")
# Out:
# 1c results:
#     1c - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(calls_by_cvlegend_and_offense.size) == '34173cb38f07f89ddbebc2ac9128303f'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in 1c 0
#         Failed example:
#             assert get_hash(calls_by_cvlegend_and_offense.size) == '34173cb38f07f89ddbebc2ac9128303f'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest 1c 0[0]>", line 1, in <module>
#                 assert get_hash(calls_by_cvlegend_and_offense.size) == '34173cb38f07f89ddbebc2ac9128303f'
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AttributeError: 'ellipsis' object has no attribute 'size'
#
#     1c - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(calls_by_cvlegend_and_offense['WEAPONS OFFENSE', 'BRANDISHING']) == '8e296a067a37563370ded05f5a3bf3ec'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in 1c 1
#         Failed example:
#             assert get_hash(calls_by_cvlegend_and_offense['WEAPONS OFFENSE', 'BRANDISHING']) == '8e296a067a37563370ded05f5a3bf3ec'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest 1c 1[0]>", line 1, in <module>
#                 assert get_hash(calls_by_cvlegend_and_offense['WEAPONS OFFENSE', 'BRANDISHING']) == '8e296a067a37563370ded05f5a3bf3ec'
#                                 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not subscriptable

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 1d (2 pts)
#
# In the cell below, set `answer1` equal to a **`list` of strings** corresponding to the possible values for `OFFENSE` when `CVLEGEND` is "LARCENY".  Use code to calculate this list (do not enter it by hand.

# %%
answer1 = ...


answer1
# Out:
# Ellipsis

# %%
grader.check("q1d")
# Out:
# q1d results:
#     q1d - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert isinstance(answer1, list)
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1d 0
#         Failed example:
#             assert isinstance(answer1, list)
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 0[0]>", line 1, in <module>
#                 assert isinstance(answer1, list)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError
#
#     q1d - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert all([isinstance(elt, str) for elt in answer1])
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1d 1
#         Failed example:
#             assert all([isinstance(elt, str) for elt in answer1])
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 1[0]>", line 1, in <module>
#                 assert all([isinstance(elt, str) for elt in answer1])
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not iterable
#
#     q1d - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(len(answer1)) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1d 2
#         Failed example:
#             assert get_hash(len(answer1)) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 2[0]>", line 1, in <module>
#                 assert get_hash(len(answer1)) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#                                 ^^^^^^^^^^^^
#             TypeError: object of type 'ellipsis' has no len()
#
#     q1d - 4 result:
#         ❌ Test case failed
#         Trying:
#             assert all([elt in calls['OFFENSE'].values for elt in answer1])
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1d 3
#         Failed example:
#             assert all([elt in calls['OFFENSE'].values for elt in answer1])
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 3[0]>", line 1, in <module>
#                 assert all([elt in calls['OFFENSE'].values for elt in answer1])
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not iterable
#
#     q1d - 5 result:
#         ❌ Test case failed
#         Trying:
#             check = list(set([a.strip().upper() for a in answer1]))
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q1d 4
#         Failed example:
#             check = list(set([a.strip().upper() for a in answer1]))
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 4[0]>", line 1, in <module>
#                 check = list(set([a.strip().upper() for a in answer1]))
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not iterable
#         Trying:
#             check.sort()
#         Expecting nothing
#         **********************************************************************
#         Line 2, in q1d 4
#         Failed example:
#             check.sort()
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 4[1]>", line 1, in <module>
#                 check.sort()
#                 ^^^^^
#             NameError: name 'check' is not defined
#         Trying:
#             assert get_hash(check) == 'bbf876a0c4e89351771267d0b1376ceb'
#         Expecting nothing
#         **********************************************************************
#         Line 3, in q1d 4
#         Failed example:
#             assert get_hash(check) == 'bbf876a0c4e89351771267d0b1376ceb'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q1d 4[2]>", line 1, in <module>
#                 assert get_hash(check) == 'bbf876a0c4e89351771267d0b1376ceb'
#                                 ^^^^^
#             NameError: name 'check' is not defined

# %% [markdown]
# <br/><br/>
#
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 3: Visualize the Data

# %% [markdown]
# ### Matplotlib demo
# Now we will explain how to work with the object-oriented plotting API mentioned in this useful [matplotlib.pyplot tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html) . In matplotlib, plotting occurs on a set of Axes which are associated with a Figure. An analogy is that on a blank canvas (Figure), you choose a location to plot (`Axes`) and then fill it in (plot).
#
# There are two approaches to labeling and manipulating figure contents, which we'll discuss below. Approach 1 is closest to the plotting paradigm of MATLAB, the namesake of matplotlib; Approach 2 is also common because many matplotlib-based packages (such as Seaborn) explicitly return the current set of axes after plotting data. Both are essentially equivalent, and at the end of this class you'll be comfortable with both.
#
# **Approach 1**: matplotlib (or Seaborn) will auto-plot onto the current set of Axes or (if none exists) create a new figure/set of default axes. You can plot data using methods from `plt`, which is shorthand for the `matplotlib.pyplot` package. Then subsequent `plt` calls all edit the same set of default-created axes.
#
# **Approach 2**:
# After creating the initial plot, you can also use `plt.gca()` to explicitly get the current set of axes, and then edit those specific axes using axes methods. Note the method naming is slightly different!

# %% [markdown]
# As an example of the built-in plotting functionality of pandas, the following example uses `plot` method of the `Series` class to generate a `barh` plot type to visually display the value counts for `CVLEGEND`.
#
# There are also many other plots that we will explore throughout the lab.

# %% [markdown]
# **Side note:** Pandas also offers basic functionality for plotting. For example, the `DataFrame` and `Series` classes both have a `plot` method, which uses matplotlib under the hood. For now we'll focus on matplotlib itself so you get used to the syntax, but just know that convenient Pandas plotting methods exist for your own future data science exploration.
#
# Below, we show both approaches by generating a horizontal bar plot to visually display the value counts for `CVLEGEND`.
#
# See the `barh`[documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html?highlight=barh#matplotlib.pyplot.barh) for more details.

# %%
# DEMO CELL: assign demo to 1 or 2.
demo = 2


calls_cvlegend = calls['CVLEGEND'].value_counts()

if demo == 1:
    plt.barh(calls_cvlegend.index, calls_cvlegend) # creates figure and axes
    print(f"Demo {demo}: Using plt methods to update plot")
    plt.ylabel("Crime Category")               # uses most recently plotted axes
    plt.xlabel("Number of Calls")
    plt.title("Number of Calls by Crime Type")

elif demo == 2:
    print(f"Demo {demo}: Using axes methods to update plot")
    plt.barh(calls_cvlegend.index, calls_cvlegend) # creates figure and axes
    ax = plt.gca()
    ax.set_ylabel("Crime Category")
    ax.set_xlabel("Number of Calls")
    ax.set_title("Axes methods: Number of Calls by Crime Type")
else:
    print("Error: Please assign the demo variable to 1 or 2.")

plt.show()
# Out:
# Demo 2: Using axes methods to update plot

# %% [markdown]
# <br/>
#
# ### An Additional Note on Plotting in Jupyter Notebooks
#
# You may have noticed that many of our plotting code cells end with a semicolon `;` or `plt.show()`. The former prevents any extra output from the last line of the cell; the latter explicitly returns (and outputs) the figure. Try adding this to your own code in the following questions!

# %% [markdown]
# [Back to top](#top)
#
# <a id='p2'></a>
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2
#
# Now it is your turn to make a plot using `matplotlib`.  Let's start by transforming the data so that it is easier to work with.
#
# The `CVDOW` field isn't named helpfully and it is hard to see the meaning from the data alone. According to the website [linked](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5) at the top of this notebook, `CVDOW` is actually indicating the day that events happened. 0->Sunday, 1->Monday ... 6->Saturday.
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2a (2 pts)
#
# For this question, you are going to read about a Pandas function we haven't covered in class and implement it.  Being able to learn new functions as you go is an important skill in data science.
#
#  - **Start by reading the documentation** for [Series.map](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.map.html).
#
#  - Then add a new column `DayType` into the `calls` dataframe.  We're going to split up the days of the week into two groups:  'Weekend' (eg.for Saturdays and Sundays) or 'Weekday' (for 'Mon' through 'Fri')  based on the corresponding value in CVDOW. For example, if the first 3 values of `CVDOW` are `[3, 6, 0]`, then the first 3 values of the `DayType` column should be `["Weekday", "Weekend", "Weekend"]`.

# %%
...
# Your code above here
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1     21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2     21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3     21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4     21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
# ...        ...                       ...                     ...     ...
# 2627  20058742      BURGLARY RESIDENTIAL  12/21/2020 12:00:00 AM   12:45
# 2628  21008017               BRANDISHING  02/24/2021 12:00:00 AM   15:06
# 2629  21013239  THEFT FELONY (OVER $950)  03/24/2021 12:00:00 AM    0:00
# 2630  21018143  THEFT MISD. (UNDER $950)  04/24/2021 12:00:00 AM   18:35
# 2631  21090258             BURGLARY AUTO  02/26/2021 12:00:00 AM    2:00
#
#                     CVLEGEND  CVDOW                InDbDate  \
# 0                    LARCENY      4  06/15/2021 12:00:00 AM
# 1                    LARCENY      4  06/15/2021 12:00:00 AM
# 2                    LARCENY      1  06/15/2021 12:00:00 AM
# 3                    LARCENY      6  06/15/2021 12:00:00 AM
# 4         BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
# ...                      ...    ...                     ...
# 2627  BURGLARY - RESIDENTIAL      1  06/15/2021 12:00:00 AM
# 2628         WEAPONS OFFENSE      3  06/15/2021 12:00:00 AM
# 2629                 LARCENY      3  06/15/2021 12:00:00 AM
# 2630                 LARCENY      6  06/15/2021 12:00:00 AM
# 2631      BURGLARY - VEHICLE      5  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 0                Berkeley, CA\n(37.869058, -122.270455)
# 1                Berkeley, CA\n(37.869058, -122.270455)
# 2     2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...
# 3     2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...
# 4     2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...
# ...                                                 ...
# 2627  1300 BLOCK UNIVERSITY AVE\nBerkeley, CA\n(37.8...
# 2628  100 BLOCK SEAWALL DR\nBerkeley, CA\n(37.863611...
# 2629  2800 BLOCK HILLEGASS AVE\nBerkeley, CA\n(37.85...
# 2630  2500 BLOCK TELEGRAPH AVE\nBerkeley, CA\n(37.86...
# 2631             Berkeley, CA\n(37.869058, -122.270455)
#
#                         BLKADDR      City State
# 0                           NaN  Berkeley    CA
# 1                           NaN  Berkeley    CA
# 2           2100 BLOCK HASTE ST  Berkeley    CA
# 3         2600 BLOCK WARRING ST  Berkeley    CA
# 4          2700 BLOCK GARBER ST  Berkeley    CA
# ...                         ...       ...   ...
# 2627  1300 BLOCK UNIVERSITY AVE  Berkeley    CA
# 2628       100 BLOCK SEAWALL DR  Berkeley    CA
# 2629   2800 BLOCK HILLEGASS AVE  Berkeley    CA
# 2630   2500 BLOCK TELEGRAPH AVE  Berkeley    CA
# 2631                        NaN  Berkeley    CA
#
# [2632 rows x 11 columns]

# %%
grader.check("q2a")
# Out:
# q2a results:
#     q2a - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert set(calls['DayType']) == set(['Weekday', 'Weekend'])
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2a 0
#         Failed example:
#             assert set(calls['DayType']) == set(['Weekday', 'Weekend'])
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                 return self._engine.get_loc(casted_key)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#               File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#             KeyError: 'DayType'
#
#             The above exception was the direct cause of the following exception:
#
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2a 0[0]>", line 1, in <module>
#                 assert set(calls['DayType']) == set(['Weekday', 'Weekend'])
#                            ~~~~~^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#                 indexer = self.columns.get_loc(key)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                 raise KeyError(key) from err
#             KeyError: 'DayType'
#
#     q2a - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(calls.loc[3, 'DayType']) == '4718c6d81f3a33c62ac04908cc7d9b71'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2a 1
#         Failed example:
#             assert get_hash(calls.loc[3, 'DayType']) == '4718c6d81f3a33c62ac04908cc7d9b71'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                 return self._engine.get_loc(casted_key)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#               File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#             KeyError: 'DayType'
#
#             The above exception was the direct cause of the following exception:
#
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2a 1[0]>", line 1, in <module>
#                 assert get_hash(calls.loc[3, 'DayType']) == '4718c6d81f3a33c62ac04908cc7d9b71'
#                                 ~~~~~~~~~^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                 return self.obj._get_value(*key, takeable=self._takeable)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                 series = self._get_item_cache(col)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                 loc = self.columns.get_loc(item)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                 raise KeyError(key) from err
#             KeyError: 'DayType'
#
#     q2a - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(calls.loc[12, 'DayType']) == '61b2ba12e6207f265362fec55427b784'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2a 2
#         Failed example:
#             assert get_hash(calls.loc[12, 'DayType']) == '61b2ba12e6207f265362fec55427b784'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                 return self._engine.get_loc(casted_key)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#               File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#             KeyError: 'DayType'
#
#             The above exception was the direct cause of the following exception:
#
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2a 2[0]>", line 1, in <module>
#                 assert get_hash(calls.loc[12, 'DayType']) == '61b2ba12e6207f265362fec55427b784'
#                                 ~~~~~~~~~^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                 return self.obj._get_value(*key, takeable=self._takeable)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                 series = self._get_item_cache(col)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                 loc = self.columns.get_loc(item)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                 raise KeyError(key) from err
#             KeyError: 'DayType'

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2b (2 pts)
#
# Now we're going to learn some basic skills for manipulating strings.
#
#  - First, **start by reading this section on Manipulating Strings**  [LDS Section 13.2 String Manipulation](https://learningds.org/ch/13/text_strings.html)
#
#  - Now let's look at the `EVENTTM` column which indicates the time for events. Since it contains hour and minute information, let's extract the hour info and create a new column named `Hour` in the `calls` dataframe. You should save the hour as an `int`.
#
#
#    - **Hint:** *Your code should only require one line*.<br/>
#    - **Hint 2:** The vectorized `Series.str[ind]` performs integer indexing on an array entry.

# %%
calls["Hour"] = ...
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1     21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2     21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3     21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4     21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
# ...        ...                       ...                     ...     ...
# 2627  20058742      BURGLARY RESIDENTIAL  12/21/2020 12:00:00 AM   12:45
# 2628  21008017               BRANDISHING  02/24/2021 12:00:00 AM   15:06
# 2629  21013239  THEFT FELONY (OVER $950)  03/24/2021 12:00:00 AM    0:00
# 2630  21018143  THEFT MISD. (UNDER $950)  04/24/2021 12:00:00 AM   18:35
# 2631  21090258             BURGLARY AUTO  02/26/2021 12:00:00 AM    2:00
#
#                     CVLEGEND  CVDOW                InDbDate  \
# 0                    LARCENY      4  06/15/2021 12:00:00 AM
# 1                    LARCENY      4  06/15/2021 12:00:00 AM
# 2                    LARCENY      1  06/15/2021 12:00:00 AM
# 3                    LARCENY      6  06/15/2021 12:00:00 AM
# 4         BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
# ...                      ...    ...                     ...
# 2627  BURGLARY - RESIDENTIAL      1  06/15/2021 12:00:00 AM
# 2628         WEAPONS OFFENSE      3  06/15/2021 12:00:00 AM
# 2629                 LARCENY      3  06/15/2021 12:00:00 AM
# 2630                 LARCENY      6  06/15/2021 12:00:00 AM
# 2631      BURGLARY - VEHICLE      5  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 0                Berkeley, CA\n(37.869058, -122.270455)
# 1                Berkeley, CA\n(37.869058, -122.270455)
# 2     2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...
# 3     2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...
# 4     2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...
# ...                                                 ...
# 2627  1300 BLOCK UNIVERSITY AVE\nBerkeley, CA\n(37.8...
# 2628  100 BLOCK SEAWALL DR\nBerkeley, CA\n(37.863611...
# 2629  2800 BLOCK HILLEGASS AVE\nBerkeley, CA\n(37.85...
# 2630  2500 BLOCK TELEGRAPH AVE\nBerkeley, CA\n(37.86...
# 2631             Berkeley, CA\n(37.869058, -122.270455)
#
#                         BLKADDR      City State      Hour
# 0                           NaN  Berkeley    CA  Ellipsis
# 1                           NaN  Berkeley    CA  Ellipsis
# 2           2100 BLOCK HASTE ST  Berkeley    CA  Ellipsis
# 3         2600 BLOCK WARRING ST  Berkeley    CA  Ellipsis
# 4          2700 BLOCK GARBER ST  Berkeley    CA  Ellipsis
# ...                         ...       ...   ...       ...
# 2627  1300 BLOCK UNIVERSITY AVE  Berkeley    CA  Ellipsis
# 2628       100 BLOCK SEAWALL DR  Berkeley    CA  Ellipsis
# 2629   2800 BLOCK HILLEGASS AVE  Berkeley    CA  Ellipsis
# 2630   2500 BLOCK TELEGRAPH AVE  Berkeley    CA  Ellipsis
# 2631                        NaN  Berkeley    CA  Ellipsis
#
# [2632 rows x 12 columns]

# %%
grader.check("q2b")
# Out:
# q2b results:
#     q2b - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2b 0
#         Failed example:
#             assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2b 0[0]>", line 1, in <module>
#                 assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError
#
#     q2b - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert calls['Hour'][72] == 18
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2b 1
#         Failed example:
#             assert calls['Hour'][72] == 18
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2b 1[0]>", line 1, in <module>
#                 assert calls['Hour'][72] == 18
#                        ^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2c (3 pts)
#
# Use seaborn to create a **density** histogram showing the distribution of calls by hour.  **Use 12 bins.**
# Include the Kernal Density Estimate (KDE) graph on your histogram.
#
# Be sure that your axes are labeled and that your plot is titled.

# %%
...
# Your code above this line

# Leave this for grading purposes
ax_3d = plt.gca()

# %% [markdown]
# <!-- END QUESTION -->
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2d (2 pts)
#
# Calculate the following summary statistics about the distribution of calls by hour (you can use built-in functions):
#
#  - i).  Mean
#  - ii).  Median
#  - iii). First Quartile
#  - iv).  Third Quartile
#  - v).  IQR

# %%
mean_hour = ...

median_hour = ...

q1 = ...

q3 = ...

IQR = ...

# %%
grader.check("q2d")
# Out:
# q2d results:
#     q2d - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(round(mean_hour, 3)) == 'cb10f7000ec889a786ea9709042b7a47'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2d 0
#         Failed example:
#             assert get_hash(round(mean_hour, 3)) == 'cb10f7000ec889a786ea9709042b7a47'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2d 0[0]>", line 1, in <module>
#                 assert get_hash(round(mean_hour, 3)) == 'cb10f7000ec889a786ea9709042b7a47'
#                                 ^^^^^^^^^^^^^^^^^^^
#             TypeError: type ellipsis doesn't define __round__ method
#
#     q2d - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(int(median_hour)) == 'aab3238922bcc25a6f606eb525ffdc56'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2d 1
#         Failed example:
#             assert get_hash(int(median_hour)) == 'aab3238922bcc25a6f606eb525ffdc56'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2d 1[0]>", line 1, in <module>
#                 assert get_hash(int(median_hour)) == 'aab3238922bcc25a6f606eb525ffdc56'
#                                 ^^^^^^^^^^^^^^^^
#             TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#     q2d - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(int(q1)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2d 2
#         Failed example:
#             assert get_hash(int(q1)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2d 2[0]>", line 1, in <module>
#                 assert get_hash(int(q1)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#                                 ^^^^^^^
#             TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#     q2d - 4 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(int(q3)) == '6f4922f45568161a8cdf4ad2299f6d23'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2d 3
#         Failed example:
#             assert get_hash(int(q3)) == '6f4922f45568161a8cdf4ad2299f6d23'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2d 3[0]>", line 1, in <module>
#                 assert get_hash(int(q3)) == '6f4922f45568161a8cdf4ad2299f6d23'
#                                 ^^^^^^^
#             TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#     q2d - 5 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(int(IQR)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q2d 4
#         Failed example:
#             assert get_hash(int(IQR)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2d 4[0]>", line 1, in <module>
#                 assert get_hash(int(IQR)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#                                 ^^^^^^^^
#             TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2e (4 pts)
#
# i).  Use seaborn to construct a box plot showing the distribution of calls by hour.
#
# ii).  To better understand the time of day a report occurs we could **stratify the analysis by DayType (i.e. by weekday vs weekends).**
#
# To do this, use seaborn to create side-by-side violin plots comparing the distribution of calls by hour on the weekend vs weekday (here's a reminder of how to create violin plots in Seaborn:  https://seaborn.pydata.org/generated/seaborn.violinplot.html)
#
# Note:  For aesthetic purposes only the violin plot continues past the end of the whiskers (i.e. past 0 and 24 hours);  however it is not possible to get data points outside of the whiskers for this distribution.

# %%
...
# Your code for boxplot above this line
# Include a title and label both axes
# Out:
# Ellipsis

# %%
...
# Your code for side-by-side violin plots above this line
# Include a title and label both axes
# Out:
# Ellipsis

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 2f (3 pts)
#
# Based on your histogram, boxplot, and violin plots above, what observations can you make about the patterns of calls? Answer each of the following questions:
#
# i).  Are there more calls in the day or at night?
#
# ii).   Approximately which hour of the day is most popular? (for example 8-9 in the morning)
#
# iii).  Approximately which hour of the day is least popular?
#
# iv).  Is there a major difference in call patterns and/or IQR between weekends and weekdays?  Explain your answer.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <br/><br/>
#
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 4: Data Faithfulness vs Reality
#
#
#
#
# Let's extract the GPS coordinates (latitude, longitude) from the `Block_Location` of each record.

# %%
# an example block location entry
calls.loc[4, 'Block_Location']
# Out:
# '2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066, -122.253407)'

# %% [markdown]
# We can use something called **regular expressions** to create a dataframe `calls_lat_lon` that has two columns titled `Lat` and `Lon`, containing the respective latitude and longitude of each record in `calls`.
#
# An in-depth coverage of regular expressions is out of the scope of CSCI 3022, but you can learn more about them in our textbook:
#  - [LDS Section 13.3: RegEx](https://learningds.org/ch/13/text_regex.html)
#  - and here `Series.str.extract` [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.extract.html?highlight=extract#pandas.Series.str.extract).
#
# Run the cell below to see how this works:

# %%
calls_lat_lon = (
    calls['Block_Location']
    .str.extract(r"\((\d+\.\d+), (-\d+\.\d+)\)")
)
calls_lat_lon.columns = ['Lat', 'Lon']

calls_lat_lon.head(10)
# Out:
#          Lat          Lon
# 0  37.869058  -122.270455
# 1  37.869058  -122.270455
# 2  37.864908  -122.267289
# 3  37.863934  -122.250262
# 4   37.86066  -122.253407
# 5  37.881957  -122.269551
# 6  37.867426  -122.269138
# 7  37.858116  -122.268002
# 8  37.868355  -122.274953
# 9  37.851491   -122.28563

# %% [markdown]
#  [Back to top](#top)
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# <a id='p3'></a>
#
#  ## 🔴 Question 3

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 3a (4 pts)
#
# Let's add the GPS data to our `calls` data. In the below cell, use the `calls_lat_lon`dataframe to add two new columns called `Lat` and `Lon` to `calls`.
#
# **Hint:** Based on how we created `calls_lat_lon` the order of records in `calls` and `calls_lat_lon` are the same.

# %%
...
# Your code above this line
calls.sample(5)      # shows a selection of random rows
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 1628  21012774     ASSAULT/BATTERY MISD.  03/24/2021 12:00:00 AM    9:08
# 1020  21090583  THEFT MISD. (UNDER $950)  05/01/2021 12:00:00 AM   13:20
# 1946  21000164  THEFT MISD. (UNDER $950)  01/02/2021 12:00:00 AM    1:30
# 1886  21023353             BURGLARY AUTO  05/26/2021 12:00:00 AM   20:30
# 621   21018204                 NARCOTICS  04/25/2021 12:00:00 AM   11:00
#
#                 CVLEGEND  CVDOW                InDbDate  \
# 1628             ASSAULT      3  06/15/2021 12:00:00 AM
# 1020             LARCENY      6  06/15/2021 12:00:00 AM
# 1946             LARCENY      6  06/15/2021 12:00:00 AM
# 1886  BURGLARY - VEHICLE      3  06/15/2021 12:00:00 AM
# 621       DRUG VIOLATION      0  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 1628  2100 BLOCK MCKINLEY AVE\nBerkeley, CA\n(37.870...
# 1020  2400 BLOCK ASHBY AVE\nBerkeley, CA\n(37.856111...
# 1946  2200 BLOCK DURANT AVE\nBerkeley, CA\n(37.86696...
# 1886  1600 BLOCK SHATTUCK AVE\nBerkeley, CA\n(37.878...
# 621   1900 BLOCK SHATTUCK AVE\nBerkeley, CA\n(37.873...
#
#                       BLKADDR      City State      Hour
# 1628  2100 BLOCK MCKINLEY AVE  Berkeley    CA  Ellipsis
# 1020     2400 BLOCK ASHBY AVE  Berkeley    CA  Ellipsis
# 1946    2200 BLOCK DURANT AVE  Berkeley    CA  Ellipsis
# 1886  1600 BLOCK SHATTUCK AVE  Berkeley    CA  Ellipsis
# 621   1900 BLOCK SHATTUCK AVE  Berkeley    CA  Ellipsis

# %%
grader.check("q3a")
# Out:
# q3a results:
#     q3a - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert 'Lat' in calls.columns and 'Lon' in calls.columns
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3a 0
#         Failed example:
#             assert 'Lat' in calls.columns and 'Lon' in calls.columns
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3a 0[0]>", line 1, in <module>
#                 assert 'Lat' in calls.columns and 'Lon' in calls.columns
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AssertionError
#
#     q3a - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(str(calls.loc[1137, 'Lat'])) == 'bd2603e4d82b4b7a0da7931835b1b997'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3a 1
#         Failed example:
#             assert get_hash(str(calls.loc[1137, 'Lat'])) == 'bd2603e4d82b4b7a0da7931835b1b997'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                 return self._engine.get_loc(casted_key)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#               File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#             KeyError: 'Lat'
#
#             The above exception was the direct cause of the following exception:
#
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3a 1[0]>", line 1, in <module>
#                 assert get_hash(str(calls.loc[1137, 'Lat'])) == 'bd2603e4d82b4b7a0da7931835b1b997'
#                                     ~~~~~~~~~^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                 return self.obj._get_value(*key, takeable=self._takeable)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                 series = self._get_item_cache(col)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                 loc = self.columns.get_loc(item)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                 raise KeyError(key) from err
#             KeyError: 'Lat'
#
#     q3a - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(str(calls.loc[689]['Lon'])) == 'd00e4be72215f07e9c0dceff1bf35e52'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3a 2
#         Failed example:
#             assert get_hash(str(calls.loc[689]['Lon'])) == 'd00e4be72215f07e9c0dceff1bf35e52'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                 return self._engine.get_loc(casted_key)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#               File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#               File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#             KeyError: 'Lon'
#
#             The above exception was the direct cause of the following exception:
#
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3a 2[0]>", line 1, in <module>
#                 assert get_hash(str(calls.loc[689]['Lon'])) == 'd00e4be72215f07e9c0dceff1bf35e52'
#                                     ~~~~~~~~~~~~~~^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/series.py", line 1121, in __getitem__
#                 return self._get_value(key)
#                        ^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/series.py", line 1237, in _get_value
#                 loc = self.index.get_loc(label)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                 raise KeyError(key) from err
#             KeyError: 'Lon'

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 3b (3 pts)
#
# #### Check for Missing Values
#
# It seems like every record has valid GPS coordinates.  We can see this by running the cell below:

# %%
# just run this cell

(calls[["Lat", "Lon"]].isna()).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 3
#       1 # just run this cell
# ----> 3 (calls[["Lat", "Lon"]].isna()).sum()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Lat', 'Lon'], dtype='object')] are in the [columns]"

# %% [markdown]
# Why exactly does this tell us every record has GPS coordinates? `calls[["Lat", "Lon"].isna()` returns a list of True (1) if that value is missing "Lat" or "Lon" column or False (0) if it doesn't. By taking the sum of this array, and seeing it is 0 for both columns, we know the list contains only False, meaning no data is missing.
#
# However, a closer examination of the data reveals something else. Here's the first few records of our data again:

# %%
calls.head(5)
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1  21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2  21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3  21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4  21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
#
#              CVLEGEND  CVDOW                InDbDate  \
# 0             LARCENY      4  06/15/2021 12:00:00 AM
# 1             LARCENY      4  06/15/2021 12:00:00 AM
# 2             LARCENY      1  06/15/2021 12:00:00 AM
# 3             LARCENY      6  06/15/2021 12:00:00 AM
# 4  BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
#
#                                       Block_Location                BLKADDR  \
# 0             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 1             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 2  2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...    2100 BLOCK HASTE ST
# 3  2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...  2600 BLOCK WARRING ST
# 4  2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...   2700 BLOCK GARBER ST
#
#        City State      Hour
# 0  Berkeley    CA  Ellipsis
# 1  Berkeley    CA  Ellipsis
# 2  Berkeley    CA  Ellipsis
# 3  Berkeley    CA  Ellipsis
# 4  Berkeley    CA  Ellipsis

# %% [markdown]
# There is another field that tells us whether we have a valid `Block_Location` entry per record---i.e., with GPS coordinates (latitude, longitude) that match the listed block location. What is it?
#
# In the below cell, use the field you found to create a new dataframe, `missing_lat_lon`, that contains only the rows of `calls` that have invalid latitude and longitude data. Your new dataframe should have all the same columns of `calls`.

# %%
missing_lat_lon = ...

missing_lat_lon.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 missing_lat_lon = ...
# ----> 3 missing_lat_lon.head()
#
# AttributeError: 'ellipsis' object has no attribute 'head'

# %%
grader.check("q3b")
# Out:
# q3b results:
#     q3b - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert missing_lat_lon.shape == (20, 16)
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3b 0
#         Failed example:
#             assert missing_lat_lon.shape == (20, 16)
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3b 0[0]>", line 1, in <module>
#                 assert missing_lat_lon.shape == (20, 16)
#                        ^^^^^^^^^^^^^^^^^^^^^
#             AttributeError: 'ellipsis' object has no attribute 'shape'
#
#     q3b - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert missing_lat_lon['BLKADDR'].isna().sum() == len(missing_lat_lon)
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3b 1
#         Failed example:
#             assert missing_lat_lon['BLKADDR'].isna().sum() == len(missing_lat_lon)
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3b 1[0]>", line 1, in <module>
#                 assert missing_lat_lon['BLKADDR'].isna().sum() == len(missing_lat_lon)
#                        ~~~~~~~~~~~~~~~^^^^^^^^^^^
#             TypeError: 'ellipsis' object is not subscriptable

# %% [markdown]
# ---
#
# ### Check Missing Values
#
# Now let us explore if there is a pattern to which types of records have missing latitude and longitude entries.
#
# First we'll create a series that collects the dates on which the missing data occurred and plot this:

# %%
# just run this cell
missing_by_time = (missing_lat_lon['EVENT_TS'] 
                   .value_counts()
                   .sort_index()
                  )
                   
                   
plt.bar(missing_by_time.index, missing_by_time)
plt.ylabel("Calls with Missing Data")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 # just run this cell
# ----> 2 missing_by_time = (missing_lat_lon['EVENT_TS']
#       3                    .value_counts()
#       4                    .sort_index()
#       5                   )
#       8 plt.bar(missing_by_time.index, missing_by_time)
#       9 plt.ylabel("Calls with Missing Data")
#
# TypeError: 'ellipsis' object is not subscriptable

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 3c (6 pts)
#
#
# i).  Create a series called `missing_by_crime` that calculates the proportion of missing lat/long data for each `CVLegend` type with  missing data.  That is, the series should **only contain `CVLegend` categories with missing lat/long data**.  For each of these CVLegend categories, the value of the series should be a fraction where the denominator is the total number of calls of that CVLegend category in the dataset and the numerator should be the number of calls of that CVLegend category with missing lat/long data.
#
# **Sort the values of the series `missing_by_crime` from highest to lowest.**
#
#
# The first few rows of your series should look as follows:
#
#
#
# | |     |
# |------|------|
# |FRAUD  | 0.021505 |
# |BURGLARY - VEHICLE     | 0.018349 |
# |BURGLARY - COMMERCIAL    |  0.011628 |
#
#
#
# For example, the first row in this tables means that $2.1505\%$ of all the fraud calls were missing lat/long data.
#
# **To receive credit**  use formatting so that all of your code can be seen in the PDF (any code that is cutoff will not receive full credit).  Tip: use newlines inside chained method calls.
#
#
# ii).  Then plot the series `missing_by_crime` as a **horizontal bar plot**. Plot the values of the series missing_by_crime starting from the lowest on the bottom to the highest on the top.  Label the x-axis.

# %% [markdown]
# <!-- BEGIN QUESTION -->

# %%
...
# Your code above this line
missing_by_crime
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 ...
#       2 # Your code above this line
# ----> 3 missing_by_crime
#
# NameError: name 'missing_by_crime' is not defined

# %%
...
# Your code to create the barplot above this line

# %%
grader.check("q3c")
# Out:
# q3c results:
#     q3c - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(len(missing_by_crime)) == 'c9f0f895fb98ab9159f51fd0297e236d'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3c 0
#         Failed example:
#             assert get_hash(len(missing_by_crime)) == 'c9f0f895fb98ab9159f51fd0297e236d'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3c 0[0]>", line 1, in <module>
#                 assert get_hash(len(missing_by_crime)) == 'c9f0f895fb98ab9159f51fd0297e236d'
#                                     ^^^^^^^^^^^^^^^^
#             NameError: name 'missing_by_crime' is not defined
#
#     q3c - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(round(missing_by_crime.iloc[0], 4)) == 'af1a898ab9e9d3c3a3ab784859ed1b08'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3c 1
#         Failed example:
#             assert get_hash(round(missing_by_crime.iloc[0], 4)) == 'af1a898ab9e9d3c3a3ab784859ed1b08'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3c 1[0]>", line 1, in <module>
#                 assert get_hash(round(missing_by_crime.iloc[0], 4)) == 'af1a898ab9e9d3c3a3ab784859ed1b08'
#                                       ^^^^^^^^^^^^^^^^
#             NameError: name 'missing_by_crime' is not defined
#
#     q3c - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(round(missing_by_crime.iloc[5], 4)) == '343b59949ee6c5497e703840fc2b537c'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3c 2
#         Failed example:
#             assert get_hash(round(missing_by_crime.iloc[5], 4)) == '343b59949ee6c5497e703840fc2b537c'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3c 2[0]>", line 1, in <module>
#                 assert get_hash(round(missing_by_crime.iloc[5], 4)) == '343b59949ee6c5497e703840fc2b537c'
#                                       ^^^^^^^^^^^^^^^^
#             NameError: name 'missing_by_crime' is not defined

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 3d (3 pts)
# Based on the plots above, give your recommendation as to how we should handle the missing data, and justify your answer:
#
# Option 1). Drop rows with missing data
#
# Option 2). Set missing data to NaN
#
# Option 3). Impute data

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Explore
#
# The below cell plots a map of phonecalls by GPS coordinates (latitude, longitude);
#
# To plot this we will first drop the missing location data.

# %%
# just run this cell to get an interactive heat map of the crime data

import folium
import folium.plugins

SF_COORDINATES = (37.87, -122.28)
sf_map = folium.Map(location=SF_COORDINATES, zoom_start=13)
locs = calls.drop(missing_lat_lon.index)[['Lat', 'Lon']].astype('float').values
heatmap = folium.plugins.HeatMap(locs.tolist(), radius=10)
sf_map.add_child(heatmap)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 8
#       6 SF_COORDINATES = (37.87, -122.28)
#       7 sf_map = folium.Map(location=SF_COORDINATES, zoom_start=13)
# ----> 8 locs = calls.drop(missing_lat_lon.index)[['Lat', 'Lon']].astype('float').values
#       9 heatmap = folium.plugins.HeatMap(locs.tolist(), radius=10)
#      10 sf_map.add_child(heatmap)
#
# AttributeError: 'ellipsis' object has no attribute 'index'

# %% [markdown]
# Based on the above map, notice that there are several drawbacks of using the location fields in this dataset to draw conclusions about crime in Berkeley.  For example:
#
#
# i).  Zoom into the map.  Notice all the calls are located on the street and often at intersections.  It's not because crimes only occurred at those locations, it's because if you examine the original data you'll notice that the locations are all anonymized to the block level.
#
#
# ii).   UC Berkeley campus is on the area of the map titled "Observatory Hill", which appears to have no calls. This is because our dataset doesn't include calls to the UC Berkeley police (which are handled by the campus police instead of the city police).   For a more complete analysis of crime in the area we may want to incorporate data from the campus police as well.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴 Question 3e (3 pts)
#
# We'll end by visualizing the number of calls as a function of time, to see if there are any seasonal patterns in call volume during the time period the data spans.
#
# Start by grouping the `calls` dataframe to create a new dataframe called `count_by_date`, with index `EVENT_TS` and column `CALL_TOT` that gives the number of calls on that specific date, sorted in chronological order.
#
# The first 5 rows of your `count_by_date` dataframe should be:
#
# |  EVENT_TS   | CALL_TOT |
# |------|------|
# |**2020-12-17**  | 10|
# |**2020-12-18**     | 18|
# |**2020-12-19**    |  14|
# |**2020-12-20**    |  14|
# |**2020-12-21**    |  16|
#
#
# Then create a lineplot displaying this data (with x-axis equal to `EVENT_TS` and y-axis equal to `CALL_TOT`).  Be sure to label your axes.

# %%
count_by_date = ...

count_by_date.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 3
#       1 count_by_date = ...
# ----> 3 count_by_date.head()
#
# AttributeError: 'ellipsis' object has no attribute 'head'

# %%
...

# Code to create a lineplot above this line
# Out:
# Ellipsis

# %%
grader.check("q3e")
# Out:
# q3e results:
#     q3e - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(count_by_date.loc['2021-06-08', 'CALL_TOT']) == 'd3d9446802a44259755d38e6d163e820'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3e 0
#         Failed example:
#             assert get_hash(count_by_date.loc['2021-06-08', 'CALL_TOT']) == 'd3d9446802a44259755d38e6d163e820'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3e 0[0]>", line 1, in <module>
#                 assert get_hash(count_by_date.loc['2021-06-08', 'CALL_TOT']) == 'd3d9446802a44259755d38e6d163e820'
#                                 ^^^^^^^^^^^^^^^^^
#             AttributeError: 'ellipsis' object has no attribute 'loc'
#
#     q3e - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(count_by_date.loc['2021-06-10', 'CALL_TOT']) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3e 1
#         Failed example:
#             assert get_hash(count_by_date.loc['2021-06-10', 'CALL_TOT']) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3e 1[0]>", line 1, in <module>
#                 assert get_hash(count_by_date.loc['2021-06-10', 'CALL_TOT']) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#                                 ^^^^^^^^^^^^^^^^^
#             AttributeError: 'ellipsis' object has no attribute 'loc'
#
#     q3e - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert get_hash(count_by_date.loc['2021-04-22', 'CALL_TOT']) == '8e296a067a37563370ded05f5a3bf3ec'
#         Expecting nothing
#         **********************************************************************
#         Line 1, in q3e 2
#         Failed example:
#             assert get_hash(count_by_date.loc['2021-04-22', 'CALL_TOT']) == '8e296a067a37563370ded05f5a3bf3ec'
#         Exception raised:
#             Traceback (most recent call last):
#               File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3e 2[0]>", line 1, in <module>
#                 assert get_hash(count_by_date.loc['2021-04-22', 'CALL_TOT']) == '8e296a067a37563370ded05f5a3bf3ec'
#                                 ^^^^^^^^^^^^^^^^^
#             AttributeError: 'ellipsis' object has no attribute 'loc'

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# <a id='p1'></a>
#
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## 🔴  Question 4: Video Assignment: Bayes' Theorem (5 pts) ##
#
# #### Complete this [Bayes' Theorem Video Assignment (click this link)](https://canvas.colorado.edu/courses/141915/assignments/2764445) available on Canvas (to receive points you must watch the entire video and answer the embedded questions).

# %% [markdown]
# <br/><br/>
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## Congratulations! You have finished Homework 3!

# %% [markdown]
# If you discussed this assignment with any other students in the class (in a manner that is acceptable as described by the Collaboration policy above) please **include their names** here:
#
# **Collaborators**: *list collaborators here*
#
# **External references**:  *list any websites you referenced*

# %% [markdown]
# ### Submission Instructions
#
#
# ## IMPORTANT STEP BEFORE COMPILING THIS ASSIGNMENT
# To **make sure all of your plots render correctly in the PDF,** please do the following steps:
#
# 1.) In the toolbar, go to Settings
# 2.) Disable Autosave Documents
#
# 3.) From the toolbar select Kernel-> Restart Kernel and Run Up to Selected Cell (up to this cell)
#
# 4.) Check that all plots are correctly displayed in this notebook and then Save.
#
# AFTER running the last cell below, open your PDF and **check that your pdf has all plots correctly showing before uploading to Gradescope - otherwise you WILL lose points**
#
# **TROUBLESHOOTING TIPS**  If you are having any issues compiling your assignment, please [read through these troubleshooting tips first](https://docs.google.com/document/d/1ndr3Wj1PSF5qzlLMaBJznwh6QGeEXjd5TAJ6nf9EJvo/edit?usp=sharing), then post any questions on Piazza.
#
# After running the `grader.export()` cell provided below, **2 files will be created**: a zip file and pdf file.  You can download them using the links provided below OR by finding them in the same folder where this juptyer notebook resides in your JuptyerHub.
#
# To receive credit on this assignment, **you must submit BOTH of these files
# to their respective Gradescope portals:**
#
# * **Homework 3 Autograded**: Submit the zip file that is output by the `grader.export()` cell below to the HW3 Autograded assignment in Gradescope.
#
# * **Homework 3 Manually Graded**: Submit your hw3.PDF to the HW3 Manually Graded assignment in Gradescope.  **YOU MUST SELECT THE PAGES CORRESPONDING TO EACH QUESTION WHEN YOU UPLOAD TO GRADESCOPE.  IF NOT, YOU WILL LOSE POINTS**   Also, **check** that all of your plots **and** all lines of your code are showing up in your PDF before submitting.  If not, you will not receive credit for your plots/code.
#
#
# **You are responsible for ensuring your submission follows our requirements. We will not be granting regrade requests nor extensions to submissions that don't follow instructions.** If you encounter any difficulties with submission, please don't hesitate to reach out to staff prior to the deadline.

# %%
# Run this cell before you run the 'grader.export()' cell below.  
# It will search for common LaTeX errors that will cause the LaTeX compiler to fail. 
import simple_latex_checker as slc

nb = slc.Nb_checker()
nb.run_check("hw03.ipynb")
# Out:
# No detected errors. Export can be run.

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# BEFORE running the cell below, SAVE your notebook.  AFTER running the cell below, click on <a href='hw03.pdf' download>this link to download the PDF </a> to upload to Gradescope.  There will be a separate link that appears after running the cell below with a link to download the zip file to upload to Gradescope.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
# Out:
# Running your submission against local test cases...
#
#
# Your submission received the following results when run against available test cases:
#
#     q1ai results:
#         q1ai - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(eventdt_type) == '9a86641cdf2fdb47f786dc955264738d'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1ai 0
#             Failed example:
#                 assert get_hash(eventdt_type) == '9a86641cdf2fdb47f786dc955264738d'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1ai 0[0]>", line 1, in <module>
#                     assert get_hash(eventdt_type) == '9a86641cdf2fdb47f786dc955264738d'
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#     q1aii results:
#         q1aii - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(calls.shape[1]) == 'c20ad4d76fe97759aa27a0c99bff6710'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1aii 0
#             Failed example:
#                 assert get_hash(calls.shape[1]) == 'c20ad4d76fe97759aa27a0c99bff6710'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1aii 0[0]>", line 1, in <module>
#                     assert get_hash(calls.shape[1]) == 'c20ad4d76fe97759aa27a0c99bff6710'
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#         q1aii - 2 result:
#             ✅ Test case passed
#
#         q1aii - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(calls.loc[1, 'EVENT_TS']) == 'cd5252ea65ebc95fc2ae8c56fb9e3b19'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1aii 2
#             Failed example:
#                 assert get_hash(calls.loc[1, 'EVENT_TS']) == 'cd5252ea65ebc95fc2ae8c56fb9e3b19'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                     return self._engine.get_loc(casted_key)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#                   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                 KeyError: 'EVENT_TS'
#
#                 The above exception was the direct cause of the following exception:
#
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1aii 2[0]>", line 1, in <module>
#                     assert get_hash(calls.loc[1, 'EVENT_TS']) == 'cd5252ea65ebc95fc2ae8c56fb9e3b19'
#                                     ~~~~~~~~~^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                     return self.obj._get_value(*key, takeable=self._takeable)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                     series = self._get_item_cache(col)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                     loc = self.columns.get_loc(item)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                     raise KeyError(key) from err
#                 KeyError: 'EVENT_TS'
#
#         q1aii - 4 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(last_event_timestamp) == '2af487344588f060428f9a266e280876'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1aii 3
#             Failed example:
#                 assert get_hash(last_event_timestamp) == '2af487344588f060428f9a266e280876'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1aii 3[0]>", line 1, in <module>
#                     assert get_hash(last_event_timestamp) == '2af487344588f060428f9a266e280876'
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#         q1aii - 5 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(first_event_timestamp) == 'c0fb5f8c6c2f8e397fe28d3358c31417'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1aii 4
#             Failed example:
#                 assert get_hash(first_event_timestamp) == 'c0fb5f8c6c2f8e397fe28d3358c31417'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1aii 4[0]>", line 1, in <module>
#                     assert get_hash(first_event_timestamp) == 'c0fb5f8c6c2f8e397fe28d3358c31417'
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#     1b results:
#         1b - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(offense_counts['ASSAULT/BATTERY MISD.']) == 'c45147dee729311ef5b5c3003946c48f'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in 1b 0
#             Failed example:
#                 assert get_hash(offense_counts['ASSAULT/BATTERY MISD.']) == 'c45147dee729311ef5b5c3003946c48f'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest 1b 0[0]>", line 1, in <module>
#                     assert get_hash(offense_counts['ASSAULT/BATTERY MISD.']) == 'c45147dee729311ef5b5c3003946c48f'
#                                     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not subscriptable
#
#         1b - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(cvlegend_counts.size) == 'b6d767d2f8ed5d21a44b0e5886680cb9'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in 1b 1
#             Failed example:
#                 assert get_hash(cvlegend_counts.size) == 'b6d767d2f8ed5d21a44b0e5886680cb9'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest 1b 1[0]>", line 1, in <module>
#                     assert get_hash(cvlegend_counts.size) == 'b6d767d2f8ed5d21a44b0e5886680cb9'
#                                     ^^^^^^^^^^^^^^^^^^^^
#                 AttributeError: 'ellipsis' object has no attribute 'size'
#
#         1b - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(cvlegend_counts['ASSAULT']) == '7ef605fc8dba5425d6965fbd4c8fbe1f'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in 1b 2
#             Failed example:
#                 assert get_hash(cvlegend_counts['ASSAULT']) == '7ef605fc8dba5425d6965fbd4c8fbe1f'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest 1b 2[0]>", line 1, in <module>
#                     assert get_hash(cvlegend_counts['ASSAULT']) == '7ef605fc8dba5425d6965fbd4c8fbe1f'
#                                     ~~~~~~~~~~~~~~~^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not subscriptable
#
#     1c results:
#         1c - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(calls_by_cvlegend_and_offense.size) == '34173cb38f07f89ddbebc2ac9128303f'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in 1c 0
#             Failed example:
#                 assert get_hash(calls_by_cvlegend_and_offense.size) == '34173cb38f07f89ddbebc2ac9128303f'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest 1c 0[0]>", line 1, in <module>
#                     assert get_hash(calls_by_cvlegend_and_offense.size) == '34173cb38f07f89ddbebc2ac9128303f'
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AttributeError: 'ellipsis' object has no attribute 'size'
#
#         1c - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(calls_by_cvlegend_and_offense['WEAPONS OFFENSE', 'BRANDISHING']) == '8e296a067a37563370ded05f5a3bf3ec'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in 1c 1
#             Failed example:
#                 assert get_hash(calls_by_cvlegend_and_offense['WEAPONS OFFENSE', 'BRANDISHING']) == '8e296a067a37563370ded05f5a3bf3ec'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest 1c 1[0]>", line 1, in <module>
#                     assert get_hash(calls_by_cvlegend_and_offense['WEAPONS OFFENSE', 'BRANDISHING']) == '8e296a067a37563370ded05f5a3bf3ec'
#                                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not subscriptable
#
#     q1d results:
#         q1d - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert isinstance(answer1, list)
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1d 0
#             Failed example:
#                 assert isinstance(answer1, list)
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 0[0]>", line 1, in <module>
#                     assert isinstance(answer1, list)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#         q1d - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert all([isinstance(elt, str) for elt in answer1])
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1d 1
#             Failed example:
#                 assert all([isinstance(elt, str) for elt in answer1])
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 1[0]>", line 1, in <module>
#                     assert all([isinstance(elt, str) for elt in answer1])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not iterable
#
#         q1d - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(len(answer1)) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1d 2
#             Failed example:
#                 assert get_hash(len(answer1)) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 2[0]>", line 1, in <module>
#                     assert get_hash(len(answer1)) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#                                     ^^^^^^^^^^^^
#                 TypeError: object of type 'ellipsis' has no len()
#
#         q1d - 4 result:
#             ❌ Test case failed
#             Trying:
#                 assert all([elt in calls['OFFENSE'].values for elt in answer1])
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1d 3
#             Failed example:
#                 assert all([elt in calls['OFFENSE'].values for elt in answer1])
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 3[0]>", line 1, in <module>
#                     assert all([elt in calls['OFFENSE'].values for elt in answer1])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not iterable
#
#         q1d - 5 result:
#             ❌ Test case failed
#             Trying:
#                 check = list(set([a.strip().upper() for a in answer1]))
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1d 4
#             Failed example:
#                 check = list(set([a.strip().upper() for a in answer1]))
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 4[0]>", line 1, in <module>
#                     check = list(set([a.strip().upper() for a in answer1]))
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not iterable
#             Trying:
#                 check.sort()
#             Expecting nothing
#             **********************************************************************
#             Line 2, in q1d 4
#             Failed example:
#                 check.sort()
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 4[1]>", line 1, in <module>
#                     check.sort()
#                     ^^^^^
#                 NameError: name 'check' is not defined
#             Trying:
#                 assert get_hash(check) == 'bbf876a0c4e89351771267d0b1376ceb'
#             Expecting nothing
#             **********************************************************************
#             Line 3, in q1d 4
#             Failed example:
#                 assert get_hash(check) == 'bbf876a0c4e89351771267d0b1376ceb'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1d 4[2]>", line 1, in <module>
#                     assert get_hash(check) == 'bbf876a0c4e89351771267d0b1376ceb'
#                                     ^^^^^
#                 NameError: name 'check' is not defined
#
#     q2a results:
#         q2a - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert set(calls['DayType']) == set(['Weekday', 'Weekend'])
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2a 0
#             Failed example:
#                 assert set(calls['DayType']) == set(['Weekday', 'Weekend'])
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                     return self._engine.get_loc(casted_key)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#                   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                 KeyError: 'DayType'
#
#                 The above exception was the direct cause of the following exception:
#
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2a 0[0]>", line 1, in <module>
#                     assert set(calls['DayType']) == set(['Weekday', 'Weekend'])
#                                ~~~~~^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#                     indexer = self.columns.get_loc(key)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                     raise KeyError(key) from err
#                 KeyError: 'DayType'
#
#         q2a - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(calls.loc[3, 'DayType']) == '4718c6d81f3a33c62ac04908cc7d9b71'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2a 1
#             Failed example:
#                 assert get_hash(calls.loc[3, 'DayType']) == '4718c6d81f3a33c62ac04908cc7d9b71'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                     return self._engine.get_loc(casted_key)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#                   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                 KeyError: 'DayType'
#
#                 The above exception was the direct cause of the following exception:
#
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2a 1[0]>", line 1, in <module>
#                     assert get_hash(calls.loc[3, 'DayType']) == '4718c6d81f3a33c62ac04908cc7d9b71'
#                                     ~~~~~~~~~^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                     return self.obj._get_value(*key, takeable=self._takeable)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                     series = self._get_item_cache(col)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                     loc = self.columns.get_loc(item)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                     raise KeyError(key) from err
#                 KeyError: 'DayType'
#
#         q2a - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(calls.loc[12, 'DayType']) == '61b2ba12e6207f265362fec55427b784'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2a 2
#             Failed example:
#                 assert get_hash(calls.loc[12, 'DayType']) == '61b2ba12e6207f265362fec55427b784'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                     return self._engine.get_loc(casted_key)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#                   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                 KeyError: 'DayType'
#
#                 The above exception was the direct cause of the following exception:
#
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2a 2[0]>", line 1, in <module>
#                     assert get_hash(calls.loc[12, 'DayType']) == '61b2ba12e6207f265362fec55427b784'
#                                     ~~~~~~~~~^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                     return self.obj._get_value(*key, takeable=self._takeable)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                     series = self._get_item_cache(col)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                     loc = self.columns.get_loc(item)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                     raise KeyError(key) from err
#                 KeyError: 'DayType'
#
#     q2b results:
#         q2b - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2b 0
#             Failed example:
#                 assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2b 0[0]>", line 1, in <module>
#                     assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#         q2b - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert calls['Hour'][72] == 18
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2b 1
#             Failed example:
#                 assert calls['Hour'][72] == 18
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2b 1[0]>", line 1, in <module>
#                     assert calls['Hour'][72] == 18
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#     q2d results:
#         q2d - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(round(mean_hour, 3)) == 'cb10f7000ec889a786ea9709042b7a47'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2d 0
#             Failed example:
#                 assert get_hash(round(mean_hour, 3)) == 'cb10f7000ec889a786ea9709042b7a47'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2d 0[0]>", line 1, in <module>
#                     assert get_hash(round(mean_hour, 3)) == 'cb10f7000ec889a786ea9709042b7a47'
#                                     ^^^^^^^^^^^^^^^^^^^
#                 TypeError: type ellipsis doesn't define __round__ method
#
#         q2d - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(int(median_hour)) == 'aab3238922bcc25a6f606eb525ffdc56'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2d 1
#             Failed example:
#                 assert get_hash(int(median_hour)) == 'aab3238922bcc25a6f606eb525ffdc56'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2d 1[0]>", line 1, in <module>
#                     assert get_hash(int(median_hour)) == 'aab3238922bcc25a6f606eb525ffdc56'
#                                     ^^^^^^^^^^^^^^^^
#                 TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#         q2d - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(int(q1)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2d 2
#             Failed example:
#                 assert get_hash(int(q1)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2d 2[0]>", line 1, in <module>
#                     assert get_hash(int(q1)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#                                     ^^^^^^^
#                 TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#         q2d - 4 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(int(q3)) == '6f4922f45568161a8cdf4ad2299f6d23'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2d 3
#             Failed example:
#                 assert get_hash(int(q3)) == '6f4922f45568161a8cdf4ad2299f6d23'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2d 3[0]>", line 1, in <module>
#                     assert get_hash(int(q3)) == '6f4922f45568161a8cdf4ad2299f6d23'
#                                     ^^^^^^^
#                 TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#         q2d - 5 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(int(IQR)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q2d 4
#             Failed example:
#                 assert get_hash(int(IQR)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q2d 4[0]>", line 1, in <module>
#                     assert get_hash(int(IQR)) == '45c48cce2e2d7fbdea1afc51c7c6ad26'
#                                     ^^^^^^^^
#                 TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'
#
#     q3a results:
#         q3a - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert 'Lat' in calls.columns and 'Lon' in calls.columns
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3a 0
#             Failed example:
#                 assert 'Lat' in calls.columns and 'Lon' in calls.columns
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3a 0[0]>", line 1, in <module>
#                     assert 'Lat' in calls.columns and 'Lon' in calls.columns
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                 AssertionError
#
#         q3a - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(str(calls.loc[1137, 'Lat'])) == 'bd2603e4d82b4b7a0da7931835b1b997'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3a 1
#             Failed example:
#                 assert get_hash(str(calls.loc[1137, 'Lat'])) == 'bd2603e4d82b4b7a0da7931835b1b997'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                     return self._engine.get_loc(casted_key)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#                   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                 KeyError: 'Lat'
#
#                 The above exception was the direct cause of the following exception:
#
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3a 1[0]>", line 1, in <module>
#                     assert get_hash(str(calls.loc[1137, 'Lat'])) == 'bd2603e4d82b4b7a0da7931835b1b997'
#                                         ~~~~~~~~~^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py", line 1183, in __getitem__
#                     return self.obj._get_value(*key, takeable=self._takeable)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4214, in _get_value
#                     series = self._get_item_cache(col)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/frame.py", line 4638, in _get_item_cache
#                     loc = self.columns.get_loc(item)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                     raise KeyError(key) from err
#                 KeyError: 'Lat'
#
#         q3a - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(str(calls.loc[689]['Lon'])) == 'd00e4be72215f07e9c0dceff1bf35e52'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3a 2
#             Failed example:
#                 assert get_hash(str(calls.loc[689]['Lon'])) == 'd00e4be72215f07e9c0dceff1bf35e52'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#                     return self._engine.get_loc(casted_key)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#                   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
#                 KeyError: 'Lon'
#
#                 The above exception was the direct cause of the following exception:
#
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3a 2[0]>", line 1, in <module>
#                     assert get_hash(str(calls.loc[689]['Lon'])) == 'd00e4be72215f07e9c0dceff1bf35e52'
#                                         ~~~~~~~~~~~~~~^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/series.py", line 1121, in __getitem__
#                     return self._get_value(key)
#                            ^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/series.py", line 1237, in _get_value
#                     loc = self.index.get_loc(label)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#                   File "/opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#                     raise KeyError(key) from err
#                 KeyError: 'Lon'
#
#     q3b results:
#         q3b - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert missing_lat_lon.shape == (20, 16)
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3b 0
#             Failed example:
#                 assert missing_lat_lon.shape == (20, 16)
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3b 0[0]>", line 1, in <module>
#                     assert missing_lat_lon.shape == (20, 16)
#                            ^^^^^^^^^^^^^^^^^^^^^
#                 AttributeError: 'ellipsis' object has no attribute 'shape'
#
#         q3b - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert missing_lat_lon['BLKADDR'].isna().sum() == len(missing_lat_lon)
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3b 1
#             Failed example:
#                 assert missing_lat_lon['BLKADDR'].isna().sum() == len(missing_lat_lon)
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3b 1[0]>", line 1, in <module>
#                     assert missing_lat_lon['BLKADDR'].isna().sum() == len(missing_lat_lon)
#                            ~~~~~~~~~~~~~~~^^^^^^^^^^^
#                 TypeError: 'ellipsis' object is not subscriptable
#
#     q3c results:
#         q3c - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(len(missing_by_crime)) == 'c9f0f895fb98ab9159f51fd0297e236d'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3c 0
#             Failed example:
#                 assert get_hash(len(missing_by_crime)) == 'c9f0f895fb98ab9159f51fd0297e236d'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3c 0[0]>", line 1, in <module>
#                     assert get_hash(len(missing_by_crime)) == 'c9f0f895fb98ab9159f51fd0297e236d'
#                                         ^^^^^^^^^^^^^^^^
#                 NameError: name 'missing_by_crime' is not defined
#
#         q3c - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(round(missing_by_crime.iloc[0], 4)) == 'af1a898ab9e9d3c3a3ab784859ed1b08'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3c 1
#             Failed example:
#                 assert get_hash(round(missing_by_crime.iloc[0], 4)) == 'af1a898ab9e9d3c3a3ab784859ed1b08'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3c 1[0]>", line 1, in <module>
#                     assert get_hash(round(missing_by_crime.iloc[0], 4)) == 'af1a898ab9e9d3c3a3ab784859ed1b08'
#                                           ^^^^^^^^^^^^^^^^
#                 NameError: name 'missing_by_crime' is not defined
#
#         q3c - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(round(missing_by_crime.iloc[5], 4)) == '343b59949ee6c5497e703840fc2b537c'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3c 2
#             Failed example:
#                 assert get_hash(round(missing_by_crime.iloc[5], 4)) == '343b59949ee6c5497e703840fc2b537c'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3c 2[0]>", line 1, in <module>
#                     assert get_hash(round(missing_by_crime.iloc[5], 4)) == '343b59949ee6c5497e703840fc2b537c'
#                                           ^^^^^^^^^^^^^^^^
#                 NameError: name 'missing_by_crime' is not defined
#
#     q3e results:
#         q3e - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(count_by_date.loc['2021-06-08', 'CALL_TOT']) == 'd3d9446802a44259755d38e6d163e820'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3e 0
#             Failed example:
#                 assert get_hash(count_by_date.loc['2021-06-08', 'CALL_TOT']) == 'd3d9446802a44259755d38e6d163e820'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3e 0[0]>", line 1, in <module>
#                     assert get_hash(count_by_date.loc['2021-06-08', 'CALL_TOT']) == 'd3d9446802a44259755d38e6d163e820'
#                                     ^^^^^^^^^^^^^^^^^
#                 AttributeError: 'ellipsis' object has no attribute 'loc'
#
#         q3e - 2 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(count_by_date.loc['2021-06-10', 'CALL_TOT']) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3e 1
#             Failed example:
#                 assert get_hash(count_by_date.loc['2021-06-10', 'CALL_TOT']) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3e 1[0]>", line 1, in <module>
#                     assert get_hash(count_by_date.loc['2021-06-10', 'CALL_TOT']) == 'eccbc87e4b5ce2fe28308fd9f2a7baf3'
#                                     ^^^^^^^^^^^^^^^^^
#                 AttributeError: 'ellipsis' object has no attribute 'loc'
#
#         q3e - 3 result:
#             ❌ Test case failed
#             Trying:
#                 assert get_hash(count_by_date.loc['2021-04-22', 'CALL_TOT']) == '8e296a067a37563370ded05f5a3bf3ec'
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q3e 2
#             Failed example:
#                 assert get_hash(count_by_date.loc['2021-04-22', 'CALL_TOT']) == '8e296a067a37563370ded05f5a3bf3ec'
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/opt/conda/lib/python3.11/doctest.py", line 1355, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q3e 2[0]>", line 1, in <module>
#                     assert get_hash(count_by_date.loc['2021-04-22', 'CALL_TOT']) == '8e296a067a37563370ded05f5a3bf3ec'
#                                     ^^^^^^^^^^^^^^^^^
#                 AttributeError: 'ellipsis' object has no attribute 'loc'
#                     <p>
#                         Your submission has been exported. Click
#                         <a href="hw03_2026_08_31T17_05_40_111474.zip" download="hw03_2026_08_31T17_05_40_111474.zip" target="_blank">here</a> to download
#                         the zip file.
#                     </p>
